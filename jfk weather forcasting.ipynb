# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv('jfk.csv',index_col= "DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.99
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  16.78
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   6.26
# 2022-10-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   4.25
# 2022-10-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.74
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT13  WT14  WT15  WT16  WT17  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   1.0   NaN
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2022-10-19   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-20   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-21   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-22   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-23   NaN   NaN  0.03   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT18  WT19  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   1.0   NaN   NaN   NaN   NaN
# 1970-01-04   1.0   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2022-10-19   NaN   NaN   NaN   NaN   NaN
# 2022-10-20   NaN   NaN   NaN   NaN   NaN
# 2022-10-21   NaN   NaN   NaN   NaN   NaN
# 2022-10-22   NaN   NaN   NaN   NaN   NaN
# 2022-10-23   NaN   NaN   NaN   NaN   NaN
#
# [19289 rows x 45 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501529
# ACSH       0.501478
# AWND       0.265177
# FMTM       0.475141
# PGTM       0.364042
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000000
# TAVG       0.680336
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501737
# WDF2       0.498574
# WDF5       0.502877
# WDFG       0.734512
# WDFM       0.999948
# WESD       0.685261
# WSF1       0.501581
# WSF2       0.498574
# WSF5       0.502929
# WSFG       0.613096
# WSFM       0.999948
# WT01       0.630256
# WT02       0.935041
# WT03       0.933278
# WT04       0.982581
# WT05       0.981129
# WT06       0.990616
# WT07       0.994401
# WT08       0.796983
# WT09       0.992742
# WT11       0.999274
# WT13       0.886723
# WT14       0.954015
# WT15       0.997823
# WT16       0.659028
# WT17       0.996889
# WT18       0.939499
# WT19       0.999948
# WT21       0.999741
# WT22       0.997460
# WV01       0.999948
# dtype: float64

# %%
valid_col = weather.columns[null_pct < 0.2]
valid_col
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_col].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.03   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2022-10-19    56    43
# 2022-10-20    61    44
# 2022-10-21    64    43
# 2022-10-22    65    43
# 2022-10-23    61    55
#
# [19289 rows x 7 columns]

# %%
weather = weather.ffill()
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-14', '2022-10-15', '2022-10-16', '2022-10-17', '2022-10-18',
#        '2022-10-19', '2022-10-20', '2022-10-21', '2022-10-22', '2022-10-23'],
#       dtype='object', name='DATE', length=19289)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-10-14', '2022-10-15', '2022-10-16', '2022-10-17',
#                '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21',
#                '2022-10-22', '2022-10-23'],
#               dtype='datetime64[ns]', name='DATE', length=19289, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    296
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.03   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43    65.0
# 2022-10-22    65    43    61.0
# 2022-10-23    61    55     NaN
#
# [19289 rows x 8 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.03   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43    65.0
# 2022-10-22    65    43    61.0
# 2022-10-23    61    55    61.0
#
# [19289 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha = .1)

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather,model,predictors,start = 3650,step = 90):
    all_predictions =[]

    for i in range(start,weather.shape[0],step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]

        model.fit(train[predictors],train["target"])

        preds = model.predict(test[predictors])

        preds = pd.Series(preds, index = test.index)
        combined = pd.concat([test["target"],preds],axis = 1)
        combined.columns = ["actual","prediction"]   
        combined["diff"] = combined["prediction"] - combined["actual"].abs()
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2022-10-19    61.0   57.030435  -3.969565
# 2022-10-20    64.0   59.784804  -4.215196
# 2022-10-21    65.0   60.609742  -4.390258
# 2022-10-22    61.0   61.057156   0.057156
# 2022-10-23    61.0   65.438039   4.438039
#
# [15639 rows x 3 columns]

# %%
weather.corr(numeric_only=True)
# Out:
#             prcp      snow      snwd      tmax      tmin    target
# prcp    1.000000  0.151053  0.001183 -0.007213  0.052278 -0.003357
# snow    0.151053  1.000000  0.232568 -0.175076 -0.159285 -0.172736
# snwd    0.001183  0.232568  1.000000 -0.259858 -0.256976 -0.241054
# tmax   -0.007213 -0.175076 -0.259858  1.000000  0.955476  0.915294
# tmin    0.052278 -0.159285 -0.256976  0.955476  1.000000  0.915453
# target -0.003357 -0.172736 -0.241054  0.915294  0.915453  1.000000

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 5.139020812384857

# %%
predictions["diff"].mean()
# Out:
# np.float64(-0.17517614726732644)

# %%
def pct_diff(old,new):
    return (new - old)/ old
def computer_rolling(weather, horizon,col):
    label = f"rollling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label],weather[col])
    return weather

rolling_horizons = [3,14]

for horizon in rolling_horizons:
    for col in ["tmax","tmin","prcp"]:
        weather = computer_rolling(weather,horizon,col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.03   0.0   0.0
#
#             tmax  tmin  target  rollling_3_tmax  rollling_3_tmax_pct  \
# DATE
# 1970-01-01    28    22    31.0              NaN                  NaN
# 1970-01-02    31    22    38.0              NaN                  NaN
# 1970-01-03    38    25    31.0        32.333333             0.175258
# 1970-01-04    31    23    35.0        33.333333            -0.070000
# 1970-01-05    35    21    36.0        34.666667             0.009615
# ...          ...   ...     ...              ...                  ...
# 2022-10-19    56    43    61.0        60.333333            -0.071823
# 2022-10-20    61    44    64.0        58.333333             0.045714
# 2022-10-21    64    43    65.0        60.333333             0.060773
# 2022-10-22    65    43    61.0        63.333333             0.026316
# 2022-10-23    61    55    61.0        63.333333            -0.036842
#
#             rollling_3_tmin  rollling_3_tmin_pct  rollling_3_prcp  \
# DATE
# 1970-01-01              NaN                  NaN              NaN
# 1970-01-02              NaN                  NaN              NaN
# 1970-01-03        23.000000             0.086957         0.006667
# 1970-01-04        23.333333            -0.014286         0.006667
# 1970-01-05        23.000000            -0.086957         0.006667
# ...                     ...                  ...              ...
# 2022-10-19        48.333333            -0.110345         0.026667
# 2022-10-20        45.000000            -0.022222         0.000000
# 2022-10-21        43.333333            -0.007692         0.000000
# 2022-10-22        43.333333            -0.007692         0.000000
# 2022-10-23        47.000000             0.170213         0.010000
#
#             rollling_3_prcp_pct  rollling_14_tmax  rollling_14_tmax_pct  \
# DATE
# 1970-01-01                  NaN               NaN                   NaN
# 1970-01-02                  NaN               NaN                   NaN
# 1970-01-03                  2.0               NaN                   NaN
# 1970-01-04                 -1.0               NaN                   NaN
# 1970-01-05                 -1.0               NaN                   NaN
# ...                         ...               ...                   ...
# 2022-10-19                 -1.0         67.000000             -0.164179
# 2022-10-20                  NaN         65.928571             -0.074756
# 2022-10-21                  NaN         65.071429             -0.016465
# 2022-10-22                  NaN         65.357143             -0.005464
# 2022-10-23                  2.0         65.142857             -0.063596
#
#             rollling_14_tmin  rollling_14_tmin_pct  rollling_14_prcp  \
# DATE
# 1970-01-01               NaN                   NaN               NaN
# 1970-01-02               NaN                   NaN               NaN
# 1970-01-03               NaN                   NaN               NaN
# 1970-01-04               NaN                   NaN               NaN
# 1970-01-05               NaN                   NaN               NaN
# ...                      ...                   ...               ...
# 2022-10-19         50.000000             -0.140000          0.095714
# 2022-10-20         49.428571             -0.109827          0.095714
# 2022-10-21         48.500000             -0.113402          0.095714
# 2022-10-22         48.285714             -0.109467          0.092857
# 2022-10-23         49.000000              0.122449          0.095000
#
#             rollling_14_prcp_pct
# DATE
# 1970-01-01                   NaN
# 1970-01-02                   NaN
# 1970-01-03                   NaN
# 1970-01-04                   NaN
# 1970-01-05                   NaN
# ...                          ...
# 2022-10-19             -1.000000
# 2022-10-20             -1.000000
# 2022-10-21             -1.000000
# 2022-10-22             -1.000000
# 2022-10-23             -0.684211
#
# [19289 rows x 20 columns]

# %%
weather = weather.iloc[14:,:]
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.03   0.0   0.0
#
#             tmax  tmin  target  rollling_3_tmax  rollling_3_tmax_pct  \
# DATE
# 1970-01-15    29    13    36.0        29.666667            -0.022472
# 1970-01-16    36    21    43.0        30.333333             0.186813
# 1970-01-17    43    30    42.0        36.000000             0.194444
# 1970-01-18    42    25    25.0        40.333333             0.041322
# 1970-01-19    25    16    24.0        36.666667            -0.318182
# ...          ...   ...     ...              ...                  ...
# 2022-10-19    56    43    61.0        60.333333            -0.071823
# 2022-10-20    61    44    64.0        58.333333             0.045714
# 2022-10-21    64    43    65.0        60.333333             0.060773
# 2022-10-22    65    43    61.0        63.333333             0.026316
# 2022-10-23    61    55    61.0        63.333333            -0.036842
#
#             rollling_3_tmin  rollling_3_tmin_pct  rollling_3_prcp  \
# DATE
# 1970-01-15        18.000000            -0.277778         0.000000
# 1970-01-16        16.666667             0.260000         0.000000
# 1970-01-17        21.333333             0.406250         0.006667
# 1970-01-18        25.333333            -0.013158         0.040000
# 1970-01-19        23.666667            -0.323944         0.040000
# ...                     ...                  ...              ...
# 2022-10-19        48.333333            -0.110345         0.026667
# 2022-10-20        45.000000            -0.022222         0.000000
# 2022-10-21        43.333333            -0.007692         0.000000
# 2022-10-22        43.333333            -0.007692         0.000000
# 2022-10-23        47.000000             0.170213         0.010000
#
#             rollling_3_prcp_pct  rollling_14_tmax  rollling_14_tmax_pct  \
# DATE
# 1970-01-15                  NaN         29.857143             -0.028708
# 1970-01-16                  NaN         30.214286              0.191489
# 1970-01-17                  2.0         30.571429              0.406542
# 1970-01-18                  1.5         31.357143              0.339408
# 1970-01-19                 -1.0         30.642857             -0.184149
# ...                         ...               ...                   ...
# 2022-10-19                 -1.0         67.000000             -0.164179
# 2022-10-20                  NaN         65.928571             -0.074756
# 2022-10-21                  NaN         65.071429             -0.016465
# 2022-10-22                  NaN         65.357143             -0.005464
# 2022-10-23                  2.0         65.142857             -0.063596
#
#             rollling_14_tmin  rollling_14_tmin_pct  rollling_14_prcp  \
# DATE
# 1970-01-15         18.857143             -0.310606          0.022857
# 1970-01-16         18.785714              0.117871          0.022857
# 1970-01-17         19.142857              0.567164          0.022857
# 1970-01-18         19.285714              0.296296          0.030000
# 1970-01-19         18.928571             -0.154717          0.030000
# ...                      ...                   ...               ...
# 2022-10-19         50.000000             -0.140000          0.095714
# 2022-10-20         49.428571             -0.109827          0.095714
# 2022-10-21         48.500000             -0.113402          0.095714
# 2022-10-22         48.285714             -0.109467          0.092857
# 2022-10-23         49.000000              0.122449          0.095000
#
#             rollling_14_prcp_pct
# DATE
# 1970-01-15             -1.000000
# 1970-01-16             -1.000000
# 1970-01-17             -0.125000
# 1970-01-18              2.333333
# 1970-01-19             -1.000000
# ...                          ...
# 2022-10-19             -1.000000
# 2022-10-20             -1.000000
# 2022-10-21             -1.000000
# 2022-10-22             -1.000000
# 2022-10-23             -0.684211
#
# [19275 rows x 20 columns]

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()
for col in ["tmax","tmin","prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys = False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys = False).apply(expand_mean)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.03   0.0   0.0
#
#             tmax  tmin  target  rollling_3_tmax  rollling_3_tmax_pct  ...  \
# DATE                                                                  ...
# 1970-01-15    29    13    36.0        29.666667            -0.022472  ...
# 1970-01-16    36    21    43.0        30.333333             0.186813  ...
# 1970-01-17    43    30    42.0        36.000000             0.194444  ...
# 1970-01-18    42    25    25.0        40.333333             0.041322  ...
# 1970-01-19    25    16    24.0        36.666667            -0.318182  ...
# ...          ...   ...     ...              ...                  ...  ...
# 2022-10-19    56    43    61.0        60.333333            -0.071823  ...
# 2022-10-20    61    44    64.0        58.333333             0.045714  ...
# 2022-10-21    64    43    65.0        60.333333             0.060773  ...
# 2022-10-22    65    43    61.0        63.333333             0.026316  ...
# 2022-10-23    61    55    61.0        63.333333            -0.036842  ...
#
#             rollling_14_tmin  rollling_14_tmin_pct  rollling_14_prcp  \
# DATE
# 1970-01-15         18.857143             -0.310606          0.022857
# 1970-01-16         18.785714              0.117871          0.022857
# 1970-01-17         19.142857              0.567164          0.022857
# 1970-01-18         19.285714              0.296296          0.030000
# 1970-01-19         18.928571             -0.154717          0.030000
# ...                      ...                   ...               ...
# 2022-10-19         50.000000             -0.140000          0.095714
# 2022-10-20         49.428571             -0.109827          0.095714
# 2022-10-21         48.500000             -0.113402          0.095714
# 2022-10-22         48.285714             -0.109467          0.092857
# 2022-10-23         49.000000              0.122449          0.095000
#
#             rollling_14_prcp_pct  month_avg_tmax  day_avg_tmax  \
# DATE
# 1970-01-15             -1.000000       29.000000     29.000000
# 1970-01-16             -1.000000       32.500000     36.000000
# 1970-01-17             -0.125000       36.000000     43.000000
# 1970-01-18              2.333333       37.500000     42.000000
# 1970-01-19             -1.000000       35.000000     25.000000
# ...                          ...             ...           ...
# 2022-10-19             -1.000000       64.833844     62.056604
# 2022-10-20             -1.000000       64.831495     62.660377
# 2022-10-21             -1.000000       64.830986     63.471698
# 2022-10-22             -1.000000       64.831089     63.584906
# 2022-10-23             -0.684211       64.828746     62.716981
#
#             month_avg_tmin  day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1970-01-15       13.000000     13.000000        0.000000      0.000000
# 1970-01-16       17.000000     21.000000        0.000000      0.000000
# 1970-01-17       21.333333     30.000000        0.006667      0.020000
# 1970-01-18       22.250000     25.000000        0.030000      0.100000
# 1970-01-19       21.000000     16.000000        0.024000      0.000000
# ...                    ...           ...             ...           ...
# 2022-10-19       50.220110     48.132075        0.115175      0.117547
# 2022-10-20       50.216299     48.471698        0.115104      0.193962
# 2022-10-21       50.211880     47.867925        0.115034      0.079057
# 2022-10-22       50.207466     48.622642        0.114963      0.104906
# 2022-10-23       50.210398     48.792453        0.114911      0.122453
#
# [19275 rows x 26 columns]

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rollling_3_tmax',
#        'rollling_3_tmax_pct', 'rollling_3_tmin', 'rollling_3_tmin_pct',
#        'rollling_3_prcp', 'rollling_3_prcp_pct', 'rollling_14_tmax',
#        'rollling_14_tmax_pct', 'rollling_14_tmin', 'rollling_14_tmin_pct',
#        'rollling_14_prcp', 'rollling_14_prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 4.792474677321332

# %%
predictions.sort_values("diff", ascending = False)
# Out:
#             actual  prediction       diff
# DATE
# 2014-01-06    20.0   42.589039  22.589039
# 2004-01-13    17.0   39.516309  22.516309
# 2019-01-20    15.0   36.823636  21.823636
# 2000-01-16    22.0   43.655611  21.655611
# 1990-03-23    37.0   57.971978  20.971978
# ...            ...         ...        ...
# 1985-04-18    84.0   58.425960 -25.574040
# 2003-04-15    86.0   59.432179 -26.567821
# 1998-03-26    80.0   51.966675 -28.033325
# 2007-03-26    78.0   49.965413 -28.034587
# 1990-03-12    85.0   54.361065 -30.638935
#
# [15625 rows x 3 columns]

# %%
weather.loc["1990-03-07":"1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
#             tmax  tmin  target  rollling_3_tmax  rollling_3_tmax_pct  ...  \
# DATE                                                                  ...
# 1990-03-07    32    14    39.0        33.666667            -0.049505  ...
# 1990-03-08    39    20    43.0        35.000000             0.114286  ...
# 1990-03-09    43    29    47.0        38.000000             0.131579  ...
# 1990-03-10    47    39    59.0        43.000000             0.093023  ...
# 1990-03-11    59    41    59.0        49.666667             0.187919  ...
# 1990-03-12    59    43    85.0        55.000000             0.072727  ...
# 1990-03-13    85    41    62.0        67.666667             0.256158  ...
# 1990-03-14    62    46    55.0        68.666667            -0.097087  ...
# 1990-03-15    55    43    62.0        67.333333            -0.183168  ...
# 1990-03-16    62    48    61.0        59.666667             0.039106  ...
# 1990-03-17    61    49    59.0        59.333333             0.028090  ...
#
#             rollling_14_tmin  rollling_14_tmin_pct  rollling_14_prcp  \
# DATE
# 1990-03-07         25.000000             -0.440000          0.047857
# 1990-03-08         24.071429             -0.169139          0.040714
# 1990-03-09         22.785714              0.272727          0.031429
# 1990-03-10         23.428571              0.664634          0.020714
# 1990-03-11         25.500000              0.607843          0.021429
# 1990-03-12         27.928571              0.539642          0.021429
# 1990-03-13         29.500000              0.389831          0.020000
# 1990-03-14         30.857143              0.490741          0.020000
# 1990-03-15         32.214286              0.334812          0.020000
# 1990-03-16         33.428571              0.435897          0.020000
# 1990-03-17         34.357143              0.426195          0.038571
#
#             rollling_14_prcp_pct  month_avg_tmax  day_avg_tmax  \
# DATE
# 1990-03-07             -1.000000       48.590112     45.428571
# 1990-03-08             -1.000000       48.574841     46.571429
# 1990-03-09             -0.681818       48.565978     45.619048
# 1990-03-10             -0.517241       48.563492     43.809524
# 1990-03-11              1.333333       48.580032     46.142857
# 1990-03-12             -1.000000       48.596519     48.142857
# 1990-03-13             -1.000000       48.654028     48.761905
# 1990-03-14             -1.000000       48.675079     50.190476
# 1990-03-15             -1.000000       48.685039     49.714286
# 1990-03-16             -1.000000       48.705975     50.095238
# 1990-03-17              5.740741       48.725275     48.095238
#
#             month_avg_tmin  day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1990-03-07       34.567783     31.857143        0.119410      0.111429
# 1990-03-08       34.544586     31.190476        0.119220      0.076667
# 1990-03-09       34.535771     30.952381        0.119046      0.036190
# 1990-03-10       34.542857     31.761905        0.118873      0.071905
# 1990-03-11       34.553090     31.904762        0.118764      0.126667
# 1990-03-12       34.566456     34.285714        0.118576      0.167619
# 1990-03-13       34.576619     34.285714        0.118389      0.091429
# 1990-03-14       34.594637     36.809524        0.118202      0.259524
# 1990-03-15       34.607874     35.761905        0.118016      0.066667
# 1990-03-16       34.628931     35.619048        0.117830      0.083810
# 1990-03-17       34.651491     34.619048        0.118053      0.079048
#
# [11 rows x 26 columns]

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>
